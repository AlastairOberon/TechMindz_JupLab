# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# %%
car_co2 = pd.read_csv(
    "/home/alastair_oberon/Shenanigans/Coding_shenanigans/Juplab_env/TM_AI_Env/Test_CSV/Car_CO2.csv"
)
car_co2
# Out:
#            Car       Model  Volume  Weight  CO2  Unnamed: 5
# 0       Toyota        Aygo    1000     790   99         NaN
# 1   Mitsubishi  Space Star    1200    1160   95         NaN
# 2        Skoda      Citigo    1000     929   95         NaN
# 3         Fiat         500     900     865   90         NaN
# 4         Mini      Cooper    1500    1140  105         NaN
# 5           VW         Up!    1000     929  105         NaN
# 6        Skoda       Fabia    1400    1109   90         NaN
# 7     Mercedes     A-Class    1500    1365   92         NaN
# 8         Ford      Fiesta    1500    1112   98         NaN
# 9         Audi          A1    1600    1150   99         NaN
# 10     Hyundai         I20    1100     980   99         NaN
# 11      Suzuki       Swift    1300     990  101         NaN
# 12        Ford      Fiesta    1000    1112   99         NaN
# 13       Honda       Civic    1600    1252   94         NaN
# 14      Hundai         I30    1600    1326   97         NaN
# ...

# %%
car_co2.drop(["Unnamed: 5"], axis = 1, inplace = True)
car_co2
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyota        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
company_enc = LabelEncoder()
model_enc = LabelEncoder()

# %%
car_co2["Car"] = company_enc.fit_transform(car_co2["Car"])
car_co2["Model"] = model_enc.fit_transform(car_co2["Model"])

# %%
x_car_co2 = car_co2.drop(["CO2"], axis = 1)
y_car_co2 = car_co2["CO2"]

# %%
x_car_co2_train,x_car_co2_test,y_car_co2_train,y_car_co2_test = train_test_split(x_car_co2,y_car_co2, test_size=0.3, random_state=1)

# %%
car_co2_model = DecisionTreeRegressor()
car_co2_model.fit(x_car_co2_train,y_car_co2_train)
# Out:
# DecisionTreeRegressor()

# %%
print(car_co2_model.score(x_car_co2_train, y_car_co2_train) * 100)
print(car_co2_model.score(x_car_co2_test, y_car_co2_test) * 100)
# Out:
# 100.0
# -65.49274019153539

# %%
ypred = car_co2_model.predict(x_car_co2_test)
ypred
# Out:
# array([102., 117., 101.,  92.,  94., 108.,  99.,  99., 108.,  94.,  94.])

# %%
r2_car_co2 = r2_score(y_car_co2_test,ypred)
print("R2_Score: ",  r2_car_co2)
# Out:
# R2_Score:  -0.6549274019153539

# %%
h_price = pd.read_csv(
    "/home/alastair_oberon/Shenanigans/Coding_shenanigans/Juplab_env/TM_AI_Env/Test_CSV/homeprices_2.csv"
)
h_price
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
h_price.isna()
# Out:
#     area  bedrooms    age  price
# 0  False     False  False  False
# 1  False     False  False  False
# 2  False      True  False  False
# 3  False     False  False  False
# 4  False     False  False  False
# 5  False     False  False  False

# %%
h_price["bedrooms"].fillna(h_price["bedrooms"].mean(), inplace=True)
h_price
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.2   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
h_price.corr()
# Out:
#               area  bedrooms       age     price
# area      1.000000  0.740910 -0.445300  0.901476
# bedrooms  0.740910  1.000000 -0.873162  0.910005
# age      -0.445300 -0.873162  1.000000 -0.734167
# price     0.901476  0.910005 -0.734167  1.000000

# %%
x1 = h_price.drop(["price"], axis=1)
y1 = h_price["price"]

# %%
x_h_price_train, x_h_price_test, y_h_price_train, y_h_price_test = train_test_split(x1, y1, test_size=0.2, random_state=1)

# %%
h_price_model = DecisionTreeRegressor()
h_price_model.fit(x_h_price_train,y_h_price_train)
# Out:
# DecisionTreeRegressor()

# %%
print(h_price_model.score(x_h_price_train, y_h_price_train) * 100)
print(h_price_model.score(x_h_price_test, y_h_price_test) * 100)
# Out:
# 100.0
# -2144.4444444444443

# %%
ypred = h_price_model.predict(x_h_price_test)
ypred
# Out:
# array([760000., 550000.])

# %%
r2_h_price = r2_score(y_h_price_test,ypred)
print("R2_Score: ",  r2_h_price)
# Out:
# R2_Score:  -21.444444444444443
