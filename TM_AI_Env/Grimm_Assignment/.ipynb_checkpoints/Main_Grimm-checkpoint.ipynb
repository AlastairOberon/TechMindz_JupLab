# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import_file = pd.read_excel(
    f"/data/Coding_Shennanigans/TechMindz/TM_AI/JupLab_env/TM_AI_Env/Grimm_Assignment/FIN Sample Data.xlsx",
    sheet_name="Sample Data",
)
import_file
# Out:
#         Ind  Gender    age_range  \
# 0    132410    Male     20 to 24
# 1     21686    Male     45 to 49
# 2      9312    Male  70 and over
# 3    209377    Male     60 to 64
# 4     41263  Female     45 to 49
# ..      ...     ...          ...
# 995  199101    Male     30 to 34
# 996   15351  Female     50 to 54
# 997  242191    Male     40 to 44
# 998  150070  Female     20 to 24
# 999  193381  Female     45 to 49
#
#                                             Occ_code Partner_status  \
# 0                                      Sales workers         Single
# 1                     Technicians and Trades Workers      Partnered
# 2    Occupation not listed/ Occupation not specified         Single
# 3                                          Labourers         Single
# 4    Occupation not listed/ Occupation not specified         Single
# ..                                               ...            ...
# 995                   Technicians and Trades Workers      Partnered
# ...

# %%
sns.set(style="whitegrid")
sns.countplot(
    y=import_file["Occ_code"],
    order=import_file["Occ_code"].value_counts(ascending=True).index,
).set(title="Occupation Code")
# Out:
# [Text(0.5, 1.0, 'Occupation Code')]
