# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
import_file = pd.read_excel(r"C:\Users\User\Desktop\FIN Tasks For Assignment.xlsx",sheet_name="Task 1 - Sample")
import_file
# Out:
#         Ind  Gender    age_range  \
# 0     41188    Male  70 and over
# 1     72485    Male     30 to 34
# 2    108268    Male     25 to 29
# 3     65459    Male     35 to 39
# 4     91243  Female     60 to 64
# ..      ...     ...          ...
# 995  136127    Male     30 to 34
# 996   66644    Male     35 to 39
# 997  131864  Female     30 to 34
# 998  198200    Male     65 to 69
# 999  246621    Male     20 to 24
#
#                                             Occ_code Partner_status  \
# 0    Occupation not listed/ Occupation not specified      Partnered
# 1                                      Professionals         Single
# 2             Community and Personal Service Workers         Single
# 3                                          Labourers      Partnered
# 4                                      Professionals      Partnered
# ..                                               ...            ...
# 995                                    Professionals         Single
# ...

# %%
Lodge_Agent = import_file[import_file["Lodgment_method"] == "Tax Agent"]
Lodge_Self = import_file[import_file["Lodgment_method"] == "Self Prepared"]
Gen_Female = import_file[import_file["Gender"] == "Female"]
Gen_Male = import_file[import_file["Gender"] == "Male"]

# %%
avg_tax_lodge_Agent = Lodge_Agent['Tot_ded_amt'].mean()
print(avg_tax_lodge_Agent)
# Out:
# 2782.8786279683377

# %%
avg_tax_lodge_Self = Lodge_Self['Tot_ded_amt'].mean()
print(avg_tax_lodge_Self)
# Out:
# 1640.1570247933885

# %%
avg_tax_Gen_Female = Gen_Female['Taxable_Income'].mean()
print(avg_tax_Gen_Female)
# Out:
# 46544.448637316564

# %%
avg_tax_Gen_Male = Gen_Male['Taxable_Income'].mean()
print(avg_tax_Gen_Male)
# Out:
# 67559.84512428298
