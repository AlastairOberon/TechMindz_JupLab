# %%
import os

import numpy as np
import pandas as pd

# %%
data = np.array([1, 2, 3, 4, 5])
data

# %%
pd.Series(data)

# %%
data.ndim

# %%
emp = {"id": [], "name": [], "age": [], "salary": []}

pf = pd.DataFrame(emp)

pf

# %%
emp_data = [
    (101, "Deepak", 25, 250000),
    (102, "Shyam", 22, 300000),
    (103, "Arun", 23, 150000),
    (104, "Manu", 20, 100000),
    (105, "Jeena", 27, 300000),
]

pf = pd.DataFrame(emp_data, columns=["id", "Name", "Age", "Salary"])
pf

# %%
emp_data_list = [
    {"id": 101, "name": "Deepak", "age": 25, "salary": 250000},
    {"id": 102, "name": "Shyam", "age": 22, "salary": 300000},
    {"id": 103, "name": "Arun", "age": 23, "salary": 150000},
    {"id": 104, "name": "Manu", "age": 20, "salary": 100000},
    {"id": 105, "name": "Jeena", "age": 27, "salary": 300000},
]

df = pd.DataFrame(emp_data_list)
df

# %%
data = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/homeprices.csv"
)  # can also be used to open and read txt files
data

# %%
print(os.getcwd())

# %%
data1 = pd.read_excel(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/Tableau_Joins_File.xlsx",
    "JobTitle",
)
data1

# %%
data3 = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv"
)
data3

# %%
data3 = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv",
    skiprows=2,
)
data3

# %%
data3 = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv",
    header=2,
)
data3

# %%
data3 = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv",
    nrows=5,
)
data3

# %%
data3 = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv",
    nrows=10,
)
data3

# %%
data3 = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv",
    names=["ticker", "eps", "revenue", "price", "people"],
)
data3

# %%
emp_data = [
    (101, "Deepak", 25, 250000),
    (102, "Shyam", 22, 300000),
    (103, "Arun", 23, 150000),
    (104, "Manu", 20, 100000),
    (105, "Jeena", 27, 300000),
]

f = pd.DataFrame(emp_data, columns=["id", "name", "age", "salary"])
f

# %%
f.to_csv(
    "/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/tocsv_amal.csv"
)

# %%
f.to_csv(
    "/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/tocsv_amal.csv",
    index=False,
    columns=["id", "name"],
)
f

# %%
f.to_excel(
    "/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/tocsv_amal.xlsx"
)

# %%
df = pd.DataFrame({"value": [10, 20, 30, 40, 50]})
df2 = pd.DataFrame({"value": [100, 200, 300, 400, 500]})
df

# %%
with pd.ExcelWriter(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/multi.xlsx"
) as wr:
    df.to_excel(wr, sheet_name="SheetA")
    df2.to_excel(wr, sheet_name="SheetB")

# %%
data = pd.read_csv(
    "/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/Churn_Modelling.csv"
)
data

# %%
def convert_people(co):
    if co == 20:
        return "Hello"

    else:
        return co

# %%
data1 = pd.read_excel(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/multi.xlsx",
    "SheetA",
    converters={"value": convert_people},
)
data1

# %%
std_data = [
    (1, "Deepak", 15, 45, 37, 24, 67),
    (2, "Shyam", 16, 46, 42, 41, 35),
    (3, "Arun", 14, 36, 39, 45, 48),
    (4, "Manu", 15, 24, 46, 37, 42),
    (5, "Jeena", 15, 47, 24, 45, 37),
]

g = pd.DataFrame(
    std_data, columns=["id", "name", "age", "mark1", "mark2", "mark3", "mark4"]
)
g.to_excel(
    "/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/toexel_marksheet.xlsx"
)

# %%
def convert_student(co):
    if co == "Manu":
        return "---"

    else:
        return co

# %%
data2 = pd.read_excel(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/toexel_marksheet.xlsx",
    converters={"name": convert_student},
)
data2

# %%
data = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv"
)
data = pd.DataFrame(data)
data

# %%
print(data.shape)

# %%
print(data.head())

# %%
print(data.tail(3))

# %%
print(data.columns)

# %%
a = data.city
a

# %%
print(data[["day", "city", "event"]])

# %%
print(data.index)

# %%
print(data.set_index("event"))

# %%
data.reset_index()

# %%
data["new_column"] = data["city"]
data

# %%
data.drop(["new_column"], axis=1)
data

# %%
data.drop(["new_column"], axis=1, inplace=True)
data

# %%
data.sort_values(["temperature"], ascending=True)
data

# %%
data.loc[4]

# %%
print(data.loc[data.city == "newyork"])

# %%
emp_data_list = [
    {"id": 101, "name": "Deepak", "age": 25, "salary": 250000},
    {"id": 102, "name": "Shyam", "age": 22, "salary": 300000},
    {"id": 103, "name": "Arun", "age": 23, "salary": 150000},
    {"id": 104, "name": "Manu", "age": 20, "salary": 100000},
    {"id": 105, "name": "Jeena", "age": 27, "salary": 300000},
]

df = pd.DataFrame(emp_data_list)
df

# %%
dat = df.set_index("name")
dat.loc[["Arun", "Manu"]]

# %%
df.iloc[2]

# %%
df.iloc[[0, 2, 4]]

# %%
df.iloc[1:2]

# %%
df.iloc[1:5]

# %%
df.dtypes

# %%
w = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv"
)
w

# %%
for i in w:
    print(i)

# %%
w[1:6]

# %%
w[:]

# %%
w[["city", "event", "temperature"]][1:4]

# %%
data

# %%
data["temperature"].max()

# %%
data.temperature.max()

# %%
data["temperature"].min()

# %%
data["temperature"].std()

# %%
data["temperature"].var()

# %%
data["city"][data.temperature == data.temperature.max()]

# %%
type(data["day"][0])

# %%
data1 = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv",
    parse_dates=["day"],
)
data1

# %%
type(data["day"][10])

# %%
data1.set_index("day")

# %%
data = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv",
    parse_dates=["day"],
    index_col="day",
)
data

# %%
dt = pd.date_range(start="2017-01-01", end="2017-07-03", freq="d")
dt

# %%
dt = pd.date_range(start="2017-01-01", end="2017-07-03", freq="ME")
dt

# %%
dt = pd.date_range(start="2017-01-01", end="2017-07-03", freq="YE")
dt

# %%
pd.to_datetime("19/5/15", yearfirst=True)

# %%
pd.to_datetime("19/5/15", dayfirst=True)

# %%
data = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/titanic.csv",
    delimiter="\t",
)
data

# %%
data.isna()

# %%
data.isna().any()

# %%
data.isna().sum()

# %%
data.isnull()

# %%
data.isnull().sum()

# %%
data.isnull().any()

# %%
print(data.isnull().any().any())

# %%
new_data = data.fillna(0)
new_data

# %%
new_data.isnull().any()

# %%
new_data1 = data.fillna({"Cabin": 0, "Age": "Unknown"})
new_data1

# %%
sample = pd.DataFrame(
    {
        "Name": ["Anu", "Amal", np.nan, "Charlie", "Vicky"],
        "Age": [np.nan, 34, np.nan, 28, 19],
        "Mark": [123, np.nan, 115, 28, np.nan],
    }
)
sample

# %%
sample["Mark"].fillna(sample["Mark"].mean(), inplace=True)
sample

# %%
new_data = sample.fillna(method="ffill")
new_data

# %%
new_data = sample.fillna(method="bfill")
new_data

# %%
s = pd.Series(
    [
        np.nan,
        "single_one",
        np.nan,
        "fill_two_more",
        np.nan,
        np.nan,
        np.nan,
        3.71,
        np.nan,
    ]
)
s

# %%
s.interpolate(method="pad", limit=1)

# %%
s.interpolate(method="backfill", limit=1)

# %%
sample

# %%
new_dif = sample.dropna()
new_dif

# %%
a = pd.DataFrame(
    {
        "name": ["muhammed", "shahil", np.nan, "anjali"],
        "age": [np.nan, 24, np.nan, np.nan],
        "mark": [np.nan, 24, np.nan, 34],
        "mark2": [np.nan, 24, np.nan, 34],
    }
)
print(a)

# %%
new_a = a.dropna(thresh=1)
new_a

# %%
data = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv",
    parse_dates=["day"],
)
data

# %%
a = data.replace(36, np.nan)
a

# %%
b = data.replace(np.nan, 32)
b

# %%
data.replace([33, "sunny"], "unknown")

# %%
data.replace({"temparate": 50, "windspeed": 12, "event": "rain"}, np.nan)

# %%
data.replace({"temparate": [92, 42], "windspeed": [7, 5], "event": "rain"}, np.nan)

# %%
data.replace({"city": "[A-Za-z]", "event": "[A-Za-z]"}, "", regex=True)

# %%
data = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv"
)
data

# %%
n = data.groupby("city")
print(n)

# %%
n.get_group("mumbai")

# %%
for city, city_df in n:
    print(city)
    print(city_df)

# %%
print(n.max())
print(n.min())
print(n.sum())

# %%
print(n.describe())

# %%
print(n.get_group("mumbai").max())

# %%
grp = data.groupby(["city", "event"])
grp

# %%
grp.get_group(("newyork", "Rain"))

# %%
for city, city_df in grp:
    print(city)
    print(city_df)

# %%
tcs = {
    "id": [101, 102, 103, 104],
    "Name": ["Midhun", "Dipin", "Jose", "Rahul"],
    "Age": [25, 26, 27, 29],
}
wipro = {
    "id": [101, 102, 103, 104],
    "Name": ["Dev", "Sreenadh", "Sreerag", "Shafeel"],
    "Age": [25, 26, 27, 29],
}
tcs_emp = pd.DataFrame(tcs)
wipro_emp = pd.DataFrame(wipro)
print(tcs_emp)
print(wipro_emp)

# %%
print(pd.concat([tcs_emp, wipro_emp]))

# %%
print(pd.concat([tcs_emp, wipro_emp], ignore_index=True))

# %%
print(pd.concat([tcs_emp, wipro_emp], keys=["TCS", "WIPRO"]))

# %%
print(pd.concat([tcs_emp, wipro_emp], axis=1))

# %%
tcs = {
    "id": [101.102, 103, 114],
    "name": ["Mithun", "Dipin", "Jose", "Rahul"],
    "Age": [25, 26, 27, 29],
}
tcs_emp = pd.DataFrame(tcs)
salary = pd.Series([65000, 75000, 15000, 25000], name="Salary")

pd.concat([tcs_emp, salary])

# %%
pd.merge(tcs_emp, wipro_emp, on="id", suffixes=["_left", "_right"])

# %%
print(tcs_emp)
print(wipro_emp)

# %%
pd.merge(tcs_emp, wipro_emp, on="id", how="outer")

# %%
pd.merge(tcs_emp, wipro_emp, on="id", how="outer", indicator=True)

# %%
pd.merge(tcs_emp, wipro_emp, on="id", how="left")

# %%
pd.merge(tcs_emp, wipro_emp, on="id", how="right")

# %%
data1 = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv",
    parse_dates=["day"],
)
data1

# %%
data1.pivot(columns="city", index="day")

# %%
data1.pivot(columns="city", index="day", values="temperature")

# %%
data1.pivot(columns="day", index="city")

# %%
data1.pivot_table(columns="day", index="city", aggfunc="sum", margins=True)

# %%
data1 = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv"
)
data1

# %%
print(pd.melt(data1, id_vars=["city"]))

# %%
pd.melt(data1, id_vars=["day"], value_name="value_1", var_name="col_name")

# %%
loan_data = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/loan_status.csv"
)
loan_data

# %%
pd.crosstab(loan_data.grade, loan_data.loan_status, margins=True)

# %%
pd.crosstab(loan_data.grade, [loan_data.loan_status, loan_data.sub_grade], margins=True)

# %%
def square(x):
    return x * 2


abc = [1, 2, 3, 4, 5]
out = list(map(square, abc))
out

# %%
data = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv"
)
data

# %%
data[["windspeed", "temperature"]].map(square)

# %%
data[["windspeed", "temperature"]].map(lambda y: y * y)

# %%
data["windspeed"].map(lambda x: x * x)

# %%
temp = pd.read_csv(
    r"/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data.csv"
)
temp
salary = pd.Series(
    [
        65000,
        75000,
        15000,
        25000,
        65000,
        75000,
        15000,
        25000,
        65000,
        75000,
        15000,
        25000,
    ],
    name="random",
)
pd.concat([temp, salary], axis=1)

# %%
temp.to_excel(
    "/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data_mod.xlsx"
)
temp.to_csv(
    "/data/Coding_Shennanigans/TechMindz/TM_AI/uv_env/TM_AI_Env/Test_CSV/weather_data_mod.csv"
)
