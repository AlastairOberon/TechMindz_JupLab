# %%
import os

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
x = ["shyam", "ashwin", "Anjana"]
y = [23, 34, 12]
plt.plot(x, y)
plt.show()

# %%
x = ["shyam", "ashwin", "anjana", "praveen", "jubil", "Shibin"]
y = [23, 34, 12, 86, 45, 34]
plt.plot(x, y)

y_2 = [45, 67, 32, 58, 65, 96]
plt.plot(x, y_2)


plt.title("Person Weight Diagram..")
plt.xlabel("Name")
plt.ylabel("Weight")
plt.legend(["Current Weight", "Needed Weight"])
plt.show()

# %%
x = ["shyam", "ashwin", "anjana", "praveen", "jubil", "Shibin"]
y = [23, 34, 12, 86, 45, 34]
plt.plot(x, y, "p--g", label="current weight")

y_2 = [45, 67, 32, 58, 65, 96]
plt.plot(x, y_2, label="needed weight", color="red", linestyle="--", marker="s")

plt.title("Person Weight Diagram..")
plt.xlabel("Name")
plt.ylabel("Weight")
plt.legend()
plt.show()

# %%
x = ["shyam", "ashwin", "anjana", "praveen", "jubil", "Shibin"]
y = [23, 34, 12, 86, 45, 34]
plt.plot(x, y, "s:c", label="current weight")

y_2 = [45, 67, 32, 58, 65, 96]
plt.plot(x, y_2, label="needed weight", c="red", linestyle="--", marker="s")

plt.title("Person Weight Diagram..")
plt.xlabel("Name")
plt.ylabel("Weight")
plt.legend()
plt.show()

# %%
x = ["shyam", "ashwin", "anjana", "praveen", "jubil", "Shibin"]
y = [23, 34, 12, 86, 45, 34]
plt.plot(x, y, "s:b", label="current weight")

y_2 = [45, 67, 32, 58, 65, 96]
plt.plot(
    x, y_2, label="needed weight", c="#ca578d", linewidth=1, linestyle="--", marker="s"
)

plt.title("Person Weight Diagram..")
plt.xlabel("Name")
plt.ylabel("Weight")
plt.legend()
plt.show()

# %%
x = ["shyam", "ashwin", "anjana", "praveen", "jubil", "Shibin"]
y = [23, 34, 12, 86, 45, 34]
plt.plot(x, y, "s--b", label="current weight")

y_2 = [45, 67, 32, 58, 65, 96]
plt.plot(
    x, y_2, label="needed weight", c="#ca578d", linewidth=5, linestyle="--", marker="s"
)

plt.title("Person Weight Diagram..")
plt.xlabel("Name")
plt.ylabel("Weight")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
x = ["shyam", "ashwin", "anjana", "praveen", "jubil", "Shibin"]
y = [23, 34, 12, 86, 45, 34]
plt.style.use("dark_background")
plt.plot(x, y, "s--b", label="current weight")

y_2 = [45, 67, 32, 58, 65, 96]
plt.plot(
    x, y_2, label="needed weight", c="#ca578d", linewidth=3, linestyle="--", marker="s"
)

plt.title("Person Weight Diagram..")
plt.xlabel("Name")
plt.ylabel("Weight")
plt.legend()
plt.grid(True)
plt.show()

# %%
x = ["shyam", "ashwin", "anjana", "praveen", "jubil", "Shibin"]
y = [23, 34, 12, 86, 45, 34]
plt.bar(x, y, label="current weight")


plt.title("Person Weight Diagram..")
plt.xlabel("Name")
plt.ylabel("Weight")
plt.legend()
plt.grid(True)
plt.show()

# %%
x = ["shyam", "ashwin", "anjana", "praveen", "jubil", "Shibin"]
y = [23, 34, 12, 86, 45, 34]
plt.style.use("dark_background")
plt.plot(x, y, "s--b", label="current weight")
plt.bar(x, y, label="current weight", color="#ca578d")

plt.title("Person Weight Diagram..")
plt.xlabel("Name")
plt.ylabel("Weight")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.style.use("dark_background")
x_range = np.arange(6)
print(x_range)
width = 0.4
y = [86, 75, 80, 75, 69, 85]
plt.bar(x_range - width, y, width=width, label="current weight", color="#ca578d")
print(x_range - width)

z = [75, 69, 85, 86, 75, 80]
plt.bar(x_range, z, width=width, label="weight needed")

plt.title("Person Age Diagram")
plt.xlabel("Name")
plt.ylabel("Weight")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [0 1 2 3 4 5]
# [-0.4  0.6  1.6  2.6  3.6  4.6]

# %%
plt.style.use("dark_background")
x_range = np.arange(6)
print(x_range)
width = 0.2
y = [86, 75, 80, 75, 69, 85]
plt.barh(x_range - width, y, label="current weight", color="#ca578d")
print(x_range - width)

z = [75, 69, 85, 86, 75, 80]
plt.barh(x_range, z, label="weight needed")

plt.title("Person Age Diagram")
plt.xlabel("Name")
plt.ylabel("Weight")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [0 1 2 3 4 5]
# [-0.2  0.8  1.8  2.8  3.8  4.8]

# %%
slices = [30, 40, 20]
labels = ["men", "women", "kids"]
colors = ["#7a834c", "blue", "yellow"]
plt.title("My Pie Chart")
plt.pie(
    slices, labels=labels, colors=colors, wedgeprops={"linewidth": 3, "edgecolor": "r"}
)
plt.show()

# %%
slices = [30, 40, 20]
labels = ["men", "women", "kids"]
colors = ["r", "b", "y"]
plt.title("My Pie Chart")
explodes = [0.1, 0.2, 0.3]
plt.pie(
    slices,
    labels=labels,
    colors=colors,
    wedgeprops={"linewidth": 3, "edgecolor": "c"},
    explode=explodes,
    shadow=True,
)
plt.show()

# %%
slices = [30, 40, 20]
labels = ["men", "women", "kids"]
colors = ["r", "b", "y"]
plt.title("My Pie Chart")
explodes = [0.1, 0.2, 0.3]
plt.pie(
    slices,
    labels=labels,
    colors=colors,
    wedgeprops={"linewidth": 3, "edgecolor": "w"},
    startangle=45,
    explode=explodes,
    autopct="%1.2f%%",
    shadow=True,
)
plt.show()

# %%
emp_data_list = [
    {"id": 101, "name": "Deepak", "age": 25, "salary": 250000},
    {"id": 102, "name": "Shyam", "age": 22, "salary": 300000},
    {"id": 103, "name": "Arun", "age": 23, "salary": 150000},
    {"id": 104, "name": "Manu", "age": 20, "salary": 100000},
    {"id": 105, "name": "Jeena", "age": 27, "salary": 300000},
]

df = pd.DataFrame(emp_data_list)
df
# Out:
#     id    name  age  salary
# 0  101  Deepak   25  250000
# 1  102   Shyam   22  300000
# 2  103    Arun   23  150000
# 3  104    Manu   20  100000
# 4  105   Jeena   27  300000

# %%
plt.title("Salary Chart")
colors = ["red", "blue", "orange", "green", "purple"]
plt.pie(
    df["salary"],
    labels=df["name"],
    colors=colors,
    # wedgeprops = {"linewidth" : 3, "edgecolor" : "w"},
    startangle=45,
    autopct="%1.2f%%",
    shadow=True,
)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f913f5ea210>,
#   <matplotlib.patches.Wedge at 0x7f913f5ea710>,
#   <matplotlib.patches.Wedge at 0x7f913f5eac10>,
#   <matplotlib.patches.Wedge at 0x7f913f5eb110>,
#   <matplotlib.patches.Wedge at 0x7f913f5eb610>],
#  [Text(0.0784730260127466, 1.0971973314716013, 'Deepak'),
#   Text(-1.0971973442564655, 0.0784728472566107, 'Shyam'),
#   Text(-0.3844103330287134, -1.030644796164398, 'Arun'),
#   Text(0.38441084905903294, -1.0306446036950436, 'Manu'),
#   Text(1.0971973511167756, -0.07847275133656836, 'Jeena')],
#  [Text(0.04280346873422541, 0.5984712717117825, '22.73%'),
#   Text(-0.5984712786853448, 0.042803371230878566, '27.27%'),
#   Text(-0.2096783634702073, -0.5621698888169444, '13.64%'),
#   Text(0.20967864494129068, -0.5621697838336601, '9.09%'),
#   Text(0.5984712824273322, -0.04280331891085547, '27.27%')])

# %%
a = np.random.randint(1, 10, 30)
b = np.random.randint(2, 15, 30)
plt.scatter(a, b)
plt.show()
print(a)
print(b)
# Out:
# [4 5 5 1 5 3 8 2 1 8 5 6 1 5 7 9 9 8 6 9 1 4 9 7 6 7 1 8 9 5]
# [ 8  2  7 14 11 13  2  4  8  6 11  6 11  8  5  3  2 13  5  2 13  7  9 10
#   8 14 11  9  8  9]

# %%
a = np.random.randint(1, 10, 30)
b = np.random.randint(2, 15, 30)
plt.scatter(a, b, s=100, color="red", marker="s", edgecolor="white", linewidth=2)
plt.show()
print(a)
print(b)
# Out:
# [4 2 7 5 3 6 5 5 8 2 8 8 7 6 1 8 3 2 9 6 2 8 5 3 2 7 9 8 8 7]
# [ 2 13  6 12  9 12  3  2  3 14  2 13  3 11 10 13 10  4 11 11 12  5 13 13
#   4 11 12  4  4 12]

# %%
a = np.random.randint(1, 10, 30)
b = np.random.randint(2, 15, 30)
colors = a
plt.style.use("seaborn-v0_8")
plt.scatter(
    a, b, s=100, c=colors, cmap="ocean", marker="s", edgecolor="black", linewidth=2
)
cbar = plt.colorbar()
cbar.set_label("color variation")
plt.show()

# %%
scatter_size = 30
a = np.random.randint(1, 200, scatter_size)
b = np.random.randint(2, 300, scatter_size)
colors = np.random.randint(1, 10, scatter_size)
plt.style.use("seaborn-v0_8")
plt.scatter(
    a,
    b,
    s=np.random.randint(50, 200, scatter_size),
    c=colors,
    cmap="ocean",
    marker="s",
    edgecolor="black",
    linewidth=2,
)
cbar = plt.colorbar()
cbar.set_label("color variation")
plt.show()

# %%
scatter_size = 30
a = np.random.randint(1, 200, scatter_size)
b = np.random.randint(2, 300, scatter_size)
colors = b
sizes = b * 5
plt.style.use("seaborn-v0_8")
plt.scatter(
    a, b, s=sizes, c=b, cmap="Greens", marker="s", edgecolor="black", linewidth=2
)
cbar = plt.colorbar()
cbar.set_label("color variation")
plt.show()

# %%
no_of_days = 9
days = np.arange(no_of_days)
studying = np.random.randint(5, 15, no_of_days)
playing = np.random.randint(5, 15, no_of_days)

plt.stackplot(
    days, studying, playing, colors=["r", "c"], labels=["Studying", "playing"]
)
plt.xlabel("days")
plt.ylabel("No. Of Days")
# Out:
# Text(0, 0.5, 'No. Of Days')

# %%
months = ["jan", "feb", "mar", "apr", "may"]
facecream = np.random.randint(2000, 4000, 5)
facewash = np.random.randint(2000, 4000, 5)
shampoo = np.random.randint(2000, 4000, 5)

plt.plot(months, facecream, label="Face Cream")
plt.plot(months, facewash, label="Face Wash")
plt.plot(months, shampoo, label="Shampoo")

plt.xlabel("Months")
plt.ylabel("Sales")
plt.title("Company Sales Data")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_range = np.arange(6)
width = 0.3

y = np.random.randint(50, 90, 6)
z = np.random.randint(50, 90, 6)
w = np.random.randint(50, 90, 6)
x_labels = ["Python", "R", "ML", "AI", "DS", "stats"]

plt.bar(x_range - width, y, width=width, label="Current Weight")
plt.bar(x_range, z, width=width, label="Weight Needed")
plt.bar(x_range + width, w, width=width, label="Ideal Weight")

plt.xticks(x_range, x_labels)

plt.title("Person Weight Comparison")
plt.xlabel("Category")
plt.ylabel("Weight")
plt.grid(True)
plt.legend()
plt.show()

# %%
Data = [
    ("Shyam", 65, "B+", 23, 120000),
    ("Sruthi", 96, "A+", 24, 115000),
    ("Arun", 71, "B+", 25, 100000),
    ("Amal", 95, "A+", 22, 150000),
    ("Ram", 90, "A", 21, 200000),
]

data = pd.DataFrame(Data, columns=["name", "Score", "Grade", "Age", "Salary"])
data
# Out:
#      name  Score Grade  Age  Salary
# 0   Shyam     65    B+   23  120000
# 1  Sruthi     96    A+   24  115000
# 2    Arun     71    B+   25  100000
# 3    Amal     95    A+   22  150000
# 4     Ram     90     A   21  200000

# %%
slices = data["Salary"]
labels = data["name"]
colors = ["red", "blue", "yellow", "green", "purple"]

plt.title("SalaryChart")
plt.pie(
    slices,
    labels=labels, 
    colors=colors, 
    wedgeprops={"linewidth": 3, "edgecolor": "w"},
    autopct="%1.2f%%"
)
plt.show()

# %%
plt.barh(data["name"], data["Salary"], label="Salary", color="red")

plt.style.use("dark_background")
plt.title("Salary Chart")
plt.xlabel("Name")
plt.ylabel("Salary")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.scatter(data["name"], data["Age"], s=50, color="red", marker="s", edgecolor="white", linewidth=2)

plt.style.use("dark_background")
plt.show()
print(a)
print(b)
# Out:
# [178 186   2  66  16 124 198  87  94  87 153  10 178  57 119 113  36 158
#   30  54  88 129  58 117  96  51  90 101 179 121]
# [165 262 206 209 285  24 209 194  95  99 293  83 255 229 258 274  16  42
#  179 113 297  97  62 214 213 141  13 235  38 131]
